# %%
import IPython
from scipy.io import wavfile
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.layers import LSTM, Dropout,Dense, BatchNormalization, GRU
from tensorflow.keras import activations
from tensorflow.keras import regularizers
from pickle import dump

from helper import *

# %%
MAX_VAL = 32768

# %%
model = tf.keras.models.load_model('../models/ae3')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# time_distributed (TimeDistri (None, 20, 2048)          2050048
# _________________________________________________________________
# lstm (LSTM)                  (None, 2048)              33562624
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 20, 2048)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 20, 2048)          33562624
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 20, 1000)          2049000
# ...
# Total params: 71,224,296
# Trainable params: 71,224,296
# Non-trainable params: 0
# _________________________________________________________________

# %%
X, y = preprocess_pipeline(start = 10, end = 12, trainTest = False, category='other')
# Out:
# beginning loading data
# 10
# 2
# 11
# 2
# concatenating data
# combinging into one np dataframe
# creating chunks
# sequencing

# %%
y.shape
# Out:
# (4480, 20, 1000)

# %%
def plot_prediction(x_true, y_true, model):
    

    x_time = fft_blocks_to_time_blocks(x_true).flatten()
    y_time = fft_blocks_to_time_blocks(y_true).flatten()
    pred = model.predict(np.array([x_true]))
    pred_time = fft_blocks_to_time_blocks(pred).flatten()

    x_len = len(x_time)
    y_len = len(y_time)
    plt.plot(np.arange(0,x_len), x_time, label = "input")
    plt.plot(np.arange(x_len,x_len+y_len), y_time, label = "real")
    plt.plot(np.arange(x_len,x_len+y_len), pred_time, label = "pred")
    plt.legend()
    plt.show()
    return np.concatenate((x_time, pred_time))

# %%
def predict_many(x_true, model, num_predictions = 30):
    curr_input = x_true
    curr_song = fft_blocks_to_time_blocks(x_true).flatten()
    for x in range(num_predictions):
        prediction = model.predict(np.array([curr_input]))[0]
        curr_song = np.concatenate((curr_song, fft_blocks_to_time_blocks(prediction[0:5]).flatten()))
        curr_input = np.concatenate((curr_input[5:], prediction[0:5, :]))
    plt.plot(curr_song)
    return curr_song

# %%
songnum = 1
plt.figure(figsize = (20,5))
song = fft_blocks_to_time_blocks(y[songnum]).flatten()
plt.plot(song)
for x in range(0, len(song) + 1, 500):
    plt.axvline(x, c='r')
plt.yticks([])
plt.xticks([x for x in range(0, 10001, 500)])
plt.xlim([0,10000])
plt.show()
print(song.max(), song.min())
# Out:
# /Users/admin/miniconda3/envs/dnnnew/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (0.4093017578125+2.0859480320466817e-17j) (-0.40093994140625+7.348057136200258e-17j)

# %%
songnum = 4400 
plot_prediction(X[songnum], y[songnum], model)
# Out:
# /Users/admin/miniconda3/envs/dnnnew/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /Users/admin/miniconda3/envs/dnnnew/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /Users/admin/miniconda3/envs/dnnnew/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# array([-0.06826782+1.83186799e-17j, -0.11138916+1.25455202e-17j,
#         0.00500488-7.66053887e-18j, ...,  0.03444822-2.50623379e-02j,
#         0.04166792+5.40038849e-02j,  0.02154673-4.70776140e-02j])

# %%
X[0] - y[0]
# Out:
# array([[-5.59503174e+00, -5.61168078e+00, -5.66615324e+00, ...,
#         -3.49432667e-01, -2.32401446e-01, -1.30871698e-01],
#        [-5.88500977e-01, -5.52701708e-01, -3.78912537e-01, ...,
#          3.12919765e-02,  4.92055583e-02, -1.21445740e-01],
#        [ 8.11248779e-01,  8.95184841e-01,  8.33011069e-01, ...,
#         -2.25901577e-03,  2.13192473e-01, -3.81901882e-02],
#        ...,
#        [-6.70806885e-01, -7.79586702e-01, -8.09059978e-01, ...,
#         -8.42534135e-02, -3.65417246e-02, -2.46718624e-02],
#        [ 4.64752197e-01,  4.72975298e-01,  2.68592555e-01, ...,
#          9.54046899e-02,  9.16160227e-02, -1.64133644e-01],
#        [ 1.73980713e-01,  1.33571320e-01,  2.01416796e-01, ...,
#         -2.01709503e-01, -2.11034817e-01,  4.88718731e-03]])

# %%
songnum = 4400
pred = predict_many(X[songnum], model)
# Out:
# /Users/admin/miniconda3/envs/dnnnew/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
IPython.display.Audio((pred * MAX_VAL).astype(int), rate=4410)
# Out:
# /Users/admin/miniconda3/envs/dnnnew/lib/python3.7/site-packages/ipykernel_launcher.py:1: ComplexWarning: Casting complex values to real discards the imaginary part
#   """Entry point for launching an IPython kernel.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
np.concatenate((X[120,:], X[121][-1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-bb66d98749be> in <module>
# ----> 1 np.concatenate((X[120,:], X[121][-1]))
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)
