# %%
import IPython
import pandas as pd
from scipy.io import wavfile

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os
import matplotlib.pyplot as plt
import numpy as np
import math

from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM, Dropout,Dense, BatchNormalization, GRU
from tensorflow.keras import activations
from tensorflow.keras import regularizers

# %%
#load file

#set your music file path
directory = '../../data/wav_csvs/downsample'
x_files = []
count=0
for filename in os.listdir(directory):
    print(filename)
    if count ==3: #only load 4 wav files 
        break
    if('xData' in filename):
        x_files.append(pd.read_csv(directory + '/' + filename, index_col=0))
        count=count+1
#concatenate into a long sequence
x_combined = pd.concat(x_files)
X = np.reshape(x_combined.values, (300*44100))
# Out:
# .DS_Store
# xData0-50-10.csv
# xData1-50-10.csv
# xData10-50-10.csv
# xData11-50-10.csv

# %%
#cut the sequence into a smaller sequence for training
X_cut = X[0:44100*2]
x_data = tf.expand_dims(X_cut,1)

# %%
#ply the sequence
samplerate= 44100/10
IPython.display.Audio(X_cut, rate=samplerate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Preprocessing

# %%
dataset = x_data
scaler = StandardScaler()
dataset = scaler.fit_transform(dataset)

training_ratio = 0.95

train_size = int(len(dataset) * training_ratio)  #select the train and validation split
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
#function to create sub sequences from a big sequence
def to_sequences(dataset, seq_size=1, output_len=32, stride = 25):
    x = []
    y = []

    for i in range(0,len(dataset)-seq_size-output_len,stride):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size:i+seq_size+output_len, 0])
        
    return np.array(x),np.array(y)

# %%
# Number of time steps to look back 
#Larger sequences (look further back) may improve forecasting.
seq_size = 300 
output_len = 150 #length of the output

trainX, trainY = to_sequences(train, seq_size, output_len)
testX, testY = to_sequences(test, seq_size, output_len)
print("Shape of training set: {}".format(trainX.shape))
print("Shape of test set: {}".format(testX.shape))

trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
# Out:
# Shape of training set: (3334, 300)
# Shape of test set: (159, 300)

# %% [markdown]
# ## Building the Model

# %%
#GRU model
#run either the GRU or the LSTM model and tune parameters for each to see which works best
def create_gru(reg_weight1 = 0, reg_weight2 = 0):
    model = tf.keras.Sequential()

    model.add(GRU(512, input_shape=(None,seq_size), 
                        return_sequences=True,
                        kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    #model.add(Dropout(0.1))

    model.add(GRU(512, return_sequences=True,
                          kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    #model.add(Dropout(0.1))

    model.add(GRU(512, return_sequences=True,
                          kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    #model.add(Dropout(0.2))

    model.add(GRU(512, return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    #model.add(Dropout(0.2))

    model.add(GRU(512, return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    # model.add(Dropout(0.2))

    model.add(GRU(512, return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    # model.add(Dropout(0.2))

    model.add(GRU(512, return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    # model.add(Dropout(0.2))

    model.add(GRU(512, return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    # model.add(Dropout(0.2))

    model.add(GRU(512, return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    # model.add(Dropout(0.2))

    model.add(GRU(512, return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    # model.add(Dropout(0.2))

    model.add(GRU(512, return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    # model.add(Dropout(0.2))

    model.add(GRU(512, return_sequences=False, kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    #model.add(Dropout(0.2))

    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(output_len))
    
    return model

# %%
#LSTM Model
def create_lstm(reg_weight1 = 0, reg_weight2 = 0):
    model = tf.keras.Sequential()

    model.add(LSTM(1024, input_shape=(None,seq_size), 
                        return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    #model.add(Dropout(0.1))

    # model.add(LSTM(1024, return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    # model.add(BatchNormalization())
    # #model.add(Dropout(0.1))

    # model.add(LSTM(512, return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    # model.add(BatchNormalization())
    # #model.add(Dropout(0.2))

    # model.add(LSTM(512, return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    # model.add(BatchNormalization())
    # #model.add(Dropout(0.2))

    model.add(LSTM(1024, return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    # model.add(Dropout(0.2))

    model.add(LSTM(1024, return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    # model.add(Dropout(0.2))

    model.add(LSTM(1024, return_sequences=True,kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    # model.add(Dropout(0.2))

    model.add(LSTM(1024, return_sequences=False, kernel_regularizer=regularizers.l1_l2(l1=reg_weight1, l2=reg_weight2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(output_len))
    
    return model

# %%
model = create_lstm()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 1024)        5427200
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 1024)        4096
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 1024)        8392704
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 1024)        4096
# _________________________________________________________________
# lstm_2 (LSTM)                (None, None, 1024)        8392704
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, 1024)        4096
# _________________________________________________________________
# lstm_3 (LSTM)                (None, None, 1024)        8392704
# _________________________________________________________________
# batch_normalization_3 (Batch (None, None, 1024)        4096
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 1024)              8392704
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# dense_1 (Dense)              (None, 150)               9750
# =================================================================
# Total params: 39,094,102
# Trainable params: 39,083,734
# Non-trainable params: 10,368
# _________________________________________________________________

# %% [markdown]
# ## Model Training

# %%
# main training cell

# #early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
#                                                   patience=3,mode='min')
opt = tf.optimizers.SGD(lr=0.05)
met = tf.metrics.MeanAbsoluteError()
model.compile(loss=tf.losses.MSE, optimizer=opt, metrics=[met])

#set the file path where the model is saved
new_filepath = 'savedmodels/'
save_best = tf.keras.callbacks.ModelCheckpoint(new_filepath, monitor='val_loss', 
                                                    verbose=1, save_best_only=True, mode='min')

history = model.fit(trainX,trainY, epochs=100,
                             validation_data=(testX,testY),
                             shuffle=True,callbacks=[save_best])
# Out:
# Epoch 1/100
#  31/105 [=======>......................] - ETA: 28s - loss: 0.9110 - mean_absolute_error: 0.6944
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-50a9293512e1> in <module>
#      14 history = model.fit(trainX,trainY, epochs=100,
#      15                              validation_data=(testX,testY),
# ---> 16                              shuffle=True,callbacks=[save_best])
#
# ~/miniconda3/envs/dnn/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/miniconda3/envs/dnn/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/miniconda3/envs/dnn/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/miniconda3/envs/dnn/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/miniconda3/envs/dnn/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/miniconda3/envs/dnn/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/miniconda3/envs/dnn/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/miniconda3/envs/dnn/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/miniconda3/envs/dnn/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
#load the model to retain
new_filepath = r'C:\Users\16177\Documents\Deep Learning Class Spring 2021\project\dnn-lofi-generation-main\practice_models\jason\saved_models'
loaded_model = keras.models.load_model(new_filepath)

# %%
trainX.shape

# %%
#retrain using predefined hyperparameters 
batch_size = [32, 32, 64, 64, 128, 256, 512, 1024, 2048]
lr = [0.05, 0.01, 0.01, 0.01, 0.05, 0.05, 0.05, 0.05, 0.05]
for i in range(len(batch_size)):
    opt = tf.optimizers.SGD(lr=lr)
    met = tf.metrics.MeanAbsoluteError()
    model.compile(loss=tf.losses.MSE, optimizer=opt, metrics=[met])
    new_history = loaded_model.fit(trainX,trainY, epochs=200,
                             validation_data=(testX,testY),
                             shuffle=True, batch_size=batch_size[i])
# Out:
# Epoch 1/200
# 105/105 [==============================] - 4s 38ms/step - loss: 0.6988 - mean_absolute_error: 0.5746 - val_loss: 0.6428 - val_mean_absolute_error: 0.6285
# Epoch 2/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.6187 - mean_absolute_error: 0.5429 - val_loss: 0.3492 - val_mean_absolute_error: 0.4514
# Epoch 3/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.5632 - mean_absolute_error: 0.5182 - val_loss: 0.3495 - val_mean_absolute_error: 0.4488
# Epoch 4/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.5343 - mean_absolute_error: 0.5068 - val_loss: 0.2792 - val_mean_absolute_error: 0.3895
# Epoch 5/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.5005 - mean_absolute_error: 0.4928 - val_loss: 0.2626 - val_mean_absolute_error: 0.3756
# Epoch 6/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.4753 - mean_absolute_error: 0.4805 - val_loss: 0.2599 - val_mean_absolute_error: 0.3727
# Epoch 7/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.4554 - mean_absolute_error: 0.4716 - val_loss: 0.2567 - val_mean_absolute_error: 0.3669
# Epoch 8/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.4434 - mean_absolute_error: 0.4669 - val_loss: 0.2710 - val_mean_absolute_error: 0.3824
# Epoch 9/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.4306 - mean_absolute_error: 0.4590 - val_loss: 0.2686 - val_mean_absolute_error: 0.3782
# Epoch 10/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.4168 - mean_absolute_error: 0.4537 - val_loss: 0.2400 - val_mean_absolute_error: 0.3528
# Epoch 11/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.3979 - mean_absolute_error: 0.4428 - val_loss: 0.2278 - val_mean_absolute_error: 0.3408
# Epoch 12/200
# 105/105 [==============================] - 2s 20ms/step - loss: 0.3840 - mean_absolute_error: 0.4359 - val_loss: 0.2879 - val_mean_absolute_error: 0.3912
# Epoch 13/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.3870 - mean_absolute_error: 0.4389 - val_loss: 0.2330 - val_mean_absolute_error: 0.3450
# Epoch 14/200
# 105/105 [==============================] - 2s 20ms/step - loss: 0.3715 - mean_absolute_error: 0.4286 - val_loss: 0.2188 - val_mean_absolute_error: 0.3316
# Epoch 15/200
# 105/105 [==============================] - 2s 20ms/step - loss: 0.3559 - mean_absolute_error: 0.4193 - val_loss: 0.2284 - val_mean_absolute_error: 0.3402
# Epoch 16/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.3496 - mean_absolute_error: 0.4167 - val_loss: 0.2349 - val_mean_absolute_error: 0.3429
# Epoch 17/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.3500 - mean_absolute_error: 0.4167 - val_loss: 0.2448 - val_mean_absolute_error: 0.3546
# Epoch 18/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.3435 - mean_absolute_error: 0.4139 - val_loss: 0.2196 - val_mean_absolute_error: 0.3317
# Epoch 19/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.3357 - mean_absolute_error: 0.4097 - val_loss: 0.2183 - val_mean_absolute_error: 0.3310
# Epoch 20/200
# 105/105 [==============================] - 2s 20ms/step - loss: 0.3272 - mean_absolute_error: 0.4035 - val_loss: 0.2277 - val_mean_absolute_error: 0.3415
# Epoch 21/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.3235 - mean_absolute_error: 0.4003 - val_loss: 0.3620 - val_mean_absolute_error: 0.4348
# Epoch 22/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.3405 - mean_absolute_error: 0.4142 - val_loss: 0.2344 - val_mean_absolute_error: 0.3454
# Epoch 23/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.3141 - mean_absolute_error: 0.3972 - val_loss: 0.2390 - val_mean_absolute_error: 0.3507
# Epoch 24/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.3126 - mean_absolute_error: 0.3974 - val_loss: 0.2079 - val_mean_absolute_error: 0.3189
# Epoch 25/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.3016 - mean_absolute_error: 0.3905 - val_loss: 0.2052 - val_mean_absolute_error: 0.3166
# Epoch 26/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2961 - mean_absolute_error: 0.3877 - val_loss: 0.2369 - val_mean_absolute_error: 0.3494
# Epoch 27/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2944 - mean_absolute_error: 0.3864 - val_loss: 0.2474 - val_mean_absolute_error: 0.3516
# Epoch 28/200
# 105/105 [==============================] - 2s 20ms/step - loss: 0.3046 - mean_absolute_error: 0.3945 - val_loss: 0.2078 - val_mean_absolute_error: 0.3180
# Epoch 29/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.2839 - mean_absolute_error: 0.3810 - val_loss: 0.3044 - val_mean_absolute_error: 0.3658
# Epoch 30/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.2845 - mean_absolute_error: 0.3801 - val_loss: 0.2179 - val_mean_absolute_error: 0.3269
# Epoch 31/200
# 105/105 [==============================] - 2s 20ms/step - loss: 0.2786 - mean_absolute_error: 0.3790 - val_loss: 0.2036 - val_mean_absolute_error: 0.3139
# Epoch 32/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2785 - mean_absolute_error: 0.3789 - val_loss: 0.2064 - val_mean_absolute_error: 0.3140
# Epoch 33/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2706 - mean_absolute_error: 0.3722 - val_loss: 0.2336 - val_mean_absolute_error: 0.3416
# Epoch 34/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2735 - mean_absolute_error: 0.3756 - val_loss: 0.1964 - val_mean_absolute_error: 0.3039
# Epoch 35/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2571 - mean_absolute_error: 0.3650 - val_loss: 0.2258 - val_mean_absolute_error: 0.3355
# Epoch 36/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2592 - mean_absolute_error: 0.3689 - val_loss: 0.2034 - val_mean_absolute_error: 0.3129
# Epoch 37/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2518 - mean_absolute_error: 0.3625 - val_loss: 0.2075 - val_mean_absolute_error: 0.3150
# Epoch 38/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.2563 - mean_absolute_error: 0.3655 - val_loss: 0.6993 - val_mean_absolute_error: 0.5439
# Epoch 39/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.2714 - mean_absolute_error: 0.3744 - val_loss: 0.2087 - val_mean_absolute_error: 0.3195
# Epoch 40/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2578 - mean_absolute_error: 0.3664 - val_loss: 0.2048 - val_mean_absolute_error: 0.3119
# Epoch 41/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2421 - mean_absolute_error: 0.3565 - val_loss: 0.2374 - val_mean_absolute_error: 0.3459
# Epoch 42/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2374 - mean_absolute_error: 0.3547 - val_loss: 0.2009 - val_mean_absolute_error: 0.3080
# Epoch 43/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2402 - mean_absolute_error: 0.3557 - val_loss: 0.2097 - val_mean_absolute_error: 0.3190
# Epoch 44/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2316 - mean_absolute_error: 0.3519 - val_loss: 0.2018 - val_mean_absolute_error: 0.3077
# Epoch 45/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2298 - mean_absolute_error: 0.3506 - val_loss: 0.2310 - val_mean_absolute_error: 0.3372
# Epoch 46/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2306 - mean_absolute_error: 0.3526 - val_loss: 0.2022 - val_mean_absolute_error: 0.3086
# Epoch 47/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2240 - mean_absolute_error: 0.3474 - val_loss: 0.1888 - val_mean_absolute_error: 0.2948
# Epoch 48/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2261 - mean_absolute_error: 0.3472 - val_loss: 0.1986 - val_mean_absolute_error: 0.3071
# Epoch 49/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2185 - mean_absolute_error: 0.3422 - val_loss: 0.4525 - val_mean_absolute_error: 0.4497
# Epoch 50/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2241 - mean_absolute_error: 0.3465 - val_loss: 0.2167 - val_mean_absolute_error: 0.3291
# Epoch 51/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2378 - mean_absolute_error: 0.3558 - val_loss: 0.1959 - val_mean_absolute_error: 0.3040
# Epoch 52/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2322 - mean_absolute_error: 0.3502 - val_loss: 0.1958 - val_mean_absolute_error: 0.3034
# Epoch 53/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2256 - mean_absolute_error: 0.3459 - val_loss: 0.2594 - val_mean_absolute_error: 0.3662
# Epoch 54/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.2153 - mean_absolute_error: 0.3417 - val_loss: 0.2122 - val_mean_absolute_error: 0.3228
# Epoch 55/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.2117 - mean_absolute_error: 0.3400 - val_loss: 0.1979 - val_mean_absolute_error: 0.3050
# Epoch 56/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.2039 - mean_absolute_error: 0.3354 - val_loss: 0.1941 - val_mean_absolute_error: 0.3002
# Epoch 57/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2009 - mean_absolute_error: 0.3325 - val_loss: 0.1900 - val_mean_absolute_error: 0.2952
# Epoch 58/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2031 - mean_absolute_error: 0.3344 - val_loss: 0.1887 - val_mean_absolute_error: 0.2918
# Epoch 59/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2283 - mean_absolute_error: 0.3435 - val_loss: 0.1842 - val_mean_absolute_error: 0.2896
# Epoch 60/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2110 - mean_absolute_error: 0.3360 - val_loss: 0.1901 - val_mean_absolute_error: 0.2965
# Epoch 61/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2038 - mean_absolute_error: 0.3330 - val_loss: 0.1855 - val_mean_absolute_error: 0.2906
# Epoch 62/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1921 - mean_absolute_error: 0.3256 - val_loss: 0.1842 - val_mean_absolute_error: 0.2886
# Epoch 63/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1924 - mean_absolute_error: 0.3266 - val_loss: 0.1814 - val_mean_absolute_error: 0.2835
# Epoch 64/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1964 - mean_absolute_error: 0.3269 - val_loss: 0.1853 - val_mean_absolute_error: 0.2891
# Epoch 65/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1912 - mean_absolute_error: 0.3235 - val_loss: 0.1804 - val_mean_absolute_error: 0.2833
# Epoch 66/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1924 - mean_absolute_error: 0.3255 - val_loss: 0.1933 - val_mean_absolute_error: 0.2973
# Epoch 67/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1854 - mean_absolute_error: 0.3208 - val_loss: 0.2863 - val_mean_absolute_error: 0.3815
# Epoch 68/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2289 - mean_absolute_error: 0.3471 - val_loss: 0.2184 - val_mean_absolute_error: 0.3243
# Epoch 69/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1985 - mean_absolute_error: 0.3323 - val_loss: 0.1841 - val_mean_absolute_error: 0.2881
# Epoch 70/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1961 - mean_absolute_error: 0.3268 - val_loss: 0.1943 - val_mean_absolute_error: 0.3012
# Epoch 71/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2143 - mean_absolute_error: 0.3349 - val_loss: 0.1836 - val_mean_absolute_error: 0.2866
# Epoch 72/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1843 - mean_absolute_error: 0.3203 - val_loss: 0.1939 - val_mean_absolute_error: 0.3000
# Epoch 73/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2042 - mean_absolute_error: 0.3337 - val_loss: 0.1864 - val_mean_absolute_error: 0.2903
# Epoch 74/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1985 - mean_absolute_error: 0.3277 - val_loss: 0.1839 - val_mean_absolute_error: 0.2890
# Epoch 75/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1800 - mean_absolute_error: 0.3157 - val_loss: 0.1825 - val_mean_absolute_error: 0.2855
# Epoch 76/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1785 - mean_absolute_error: 0.3152 - val_loss: 0.1885 - val_mean_absolute_error: 0.2931
# Epoch 77/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1852 - mean_absolute_error: 0.3186 - val_loss: 0.1748 - val_mean_absolute_error: 0.2741
# Epoch 78/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1788 - mean_absolute_error: 0.3164 - val_loss: 0.1796 - val_mean_absolute_error: 0.2805
# Epoch 79/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1766 - mean_absolute_error: 0.3151 - val_loss: 0.1914 - val_mean_absolute_error: 0.2953
# Epoch 80/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1717 - mean_absolute_error: 0.3106 - val_loss: 0.1842 - val_mean_absolute_error: 0.2877
# Epoch 81/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1779 - mean_absolute_error: 0.3158 - val_loss: 0.1929 - val_mean_absolute_error: 0.2985
# Epoch 82/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1814 - mean_absolute_error: 0.3163 - val_loss: 0.1968 - val_mean_absolute_error: 0.3029
# Epoch 83/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1851 - mean_absolute_error: 0.3192 - val_loss: 0.1797 - val_mean_absolute_error: 0.2820
# Epoch 84/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1705 - mean_absolute_error: 0.3083 - val_loss: 0.1738 - val_mean_absolute_error: 0.2757
# Epoch 85/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1683 - mean_absolute_error: 0.3075 - val_loss: 0.1771 - val_mean_absolute_error: 0.2780
# Epoch 86/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1704 - mean_absolute_error: 0.3102 - val_loss: 0.1818 - val_mean_absolute_error: 0.2843
# Epoch 87/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1655 - mean_absolute_error: 0.3059 - val_loss: 0.1865 - val_mean_absolute_error: 0.2879
# Epoch 88/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1611 - mean_absolute_error: 0.3016 - val_loss: 0.1809 - val_mean_absolute_error: 0.2839
# Epoch 89/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1655 - mean_absolute_error: 0.3051 - val_loss: 0.1821 - val_mean_absolute_error: 0.2843
# Epoch 90/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1604 - mean_absolute_error: 0.3009 - val_loss: 0.1874 - val_mean_absolute_error: 0.2922
# Epoch 91/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1620 - mean_absolute_error: 0.3026 - val_loss: 0.1787 - val_mean_absolute_error: 0.2814
# Epoch 92/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1639 - mean_absolute_error: 0.3048 - val_loss: 0.1781 - val_mean_absolute_error: 0.2786
# Epoch 93/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1558 - mean_absolute_error: 0.2971 - val_loss: 0.1785 - val_mean_absolute_error: 0.2802
# Epoch 94/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1566 - mean_absolute_error: 0.2981 - val_loss: 0.1742 - val_mean_absolute_error: 0.2749
# Epoch 95/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1595 - mean_absolute_error: 0.2991 - val_loss: 1.0165 - val_mean_absolute_error: 0.6077
# Epoch 96/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1786 - mean_absolute_error: 0.3122 - val_loss: 0.9707 - val_mean_absolute_error: 0.6513
# Epoch 97/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1871 - mean_absolute_error: 0.3222 - val_loss: 0.1765 - val_mean_absolute_error: 0.2776
# Epoch 98/200
# 105/105 [==============================] - 2s 20ms/step - loss: 0.1676 - mean_absolute_error: 0.3080 - val_loss: 0.2262 - val_mean_absolute_error: 0.3350
# Epoch 99/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1770 - mean_absolute_error: 0.3158 - val_loss: 0.1867 - val_mean_absolute_error: 0.2906
# Epoch 100/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1609 - mean_absolute_error: 0.3026 - val_loss: 0.1730 - val_mean_absolute_error: 0.2735
# Epoch 101/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1586 - mean_absolute_error: 0.3002 - val_loss: 0.1736 - val_mean_absolute_error: 0.2732
# Epoch 102/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1575 - mean_absolute_error: 0.2992 - val_loss: 0.1725 - val_mean_absolute_error: 0.2708
# Epoch 103/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1548 - mean_absolute_error: 0.2970 - val_loss: 0.2050 - val_mean_absolute_error: 0.3116
# Epoch 104/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1649 - mean_absolute_error: 0.3060 - val_loss: 0.1776 - val_mean_absolute_error: 0.2766
# Epoch 105/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1524 - mean_absolute_error: 0.2941 - val_loss: 0.1711 - val_mean_absolute_error: 0.2710
# Epoch 106/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1554 - mean_absolute_error: 0.2975 - val_loss: 0.1736 - val_mean_absolute_error: 0.2744
# Epoch 107/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1536 - mean_absolute_error: 0.2962 - val_loss: 0.1747 - val_mean_absolute_error: 0.2737
# Epoch 108/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1542 - mean_absolute_error: 0.2964 - val_loss: 0.1939 - val_mean_absolute_error: 0.2997
# Epoch 109/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1539 - mean_absolute_error: 0.2964 - val_loss: 0.1746 - val_mean_absolute_error: 0.2745
# Epoch 110/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1510 - mean_absolute_error: 0.2940 - val_loss: 0.1707 - val_mean_absolute_error: 0.2692
# Epoch 111/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1483 - mean_absolute_error: 0.2905 - val_loss: 0.1701 - val_mean_absolute_error: 0.2678
# Epoch 112/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1491 - mean_absolute_error: 0.2918 - val_loss: 0.1695 - val_mean_absolute_error: 0.2677
# Epoch 113/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1486 - mean_absolute_error: 0.2914 - val_loss: 0.1683 - val_mean_absolute_error: 0.2662
# Epoch 114/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1469 - mean_absolute_error: 0.2894 - val_loss: 0.1771 - val_mean_absolute_error: 0.2777
# Epoch 115/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1453 - mean_absolute_error: 0.2879 - val_loss: 0.1686 - val_mean_absolute_error: 0.2670
# Epoch 116/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1436 - mean_absolute_error: 0.2862 - val_loss: 0.1776 - val_mean_absolute_error: 0.2802
# Epoch 117/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1473 - mean_absolute_error: 0.2893 - val_loss: 0.2010 - val_mean_absolute_error: 0.3040
# Epoch 118/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1842 - mean_absolute_error: 0.3151 - val_loss: 0.1833 - val_mean_absolute_error: 0.2858
# Epoch 119/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1688 - mean_absolute_error: 0.3010 - val_loss: 0.1812 - val_mean_absolute_error: 0.2843
# Epoch 120/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1598 - mean_absolute_error: 0.2987 - val_loss: 0.1729 - val_mean_absolute_error: 0.2734
# Epoch 121/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1481 - mean_absolute_error: 0.2890 - val_loss: 0.3321 - val_mean_absolute_error: 0.4109
# Epoch 122/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1742 - mean_absolute_error: 0.3106 - val_loss: 0.1812 - val_mean_absolute_error: 0.2822
# Epoch 123/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1479 - mean_absolute_error: 0.2902 - val_loss: 0.1726 - val_mean_absolute_error: 0.2725
# Epoch 124/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1495 - mean_absolute_error: 0.2920 - val_loss: 0.1717 - val_mean_absolute_error: 0.2701
# Epoch 125/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1474 - mean_absolute_error: 0.2910 - val_loss: 0.1696 - val_mean_absolute_error: 0.2682
# Epoch 126/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1433 - mean_absolute_error: 0.2862 - val_loss: 0.1749 - val_mean_absolute_error: 0.2751
# Epoch 127/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1416 - mean_absolute_error: 0.2843 - val_loss: 0.1830 - val_mean_absolute_error: 0.2853
# Epoch 128/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1482 - mean_absolute_error: 0.2918 - val_loss: 0.1722 - val_mean_absolute_error: 0.2715
# Epoch 129/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1420 - mean_absolute_error: 0.2853 - val_loss: 0.1717 - val_mean_absolute_error: 0.2709
# Epoch 130/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1401 - mean_absolute_error: 0.2826 - val_loss: 0.2257 - val_mean_absolute_error: 0.3244
# Epoch 131/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1456 - mean_absolute_error: 0.2877 - val_loss: 0.2611 - val_mean_absolute_error: 0.3561
# Epoch 132/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2111 - mean_absolute_error: 0.3320 - val_loss: 0.1903 - val_mean_absolute_error: 0.2946
# Epoch 133/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1641 - mean_absolute_error: 0.2993 - val_loss: 0.1821 - val_mean_absolute_error: 0.2838
# Epoch 134/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1605 - mean_absolute_error: 0.2967 - val_loss: 0.1851 - val_mean_absolute_error: 0.2885
# Epoch 135/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1596 - mean_absolute_error: 0.2993 - val_loss: 0.1826 - val_mean_absolute_error: 0.2853
# Epoch 136/200
# 105/105 [==============================] - 2s 20ms/step - loss: 0.1466 - mean_absolute_error: 0.2893 - val_loss: 0.3717 - val_mean_absolute_error: 0.4043
# Epoch 137/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1478 - mean_absolute_error: 0.2910 - val_loss: 0.1709 - val_mean_absolute_error: 0.2694
# Epoch 138/200
# 105/105 [==============================] - 2s 20ms/step - loss: 0.1441 - mean_absolute_error: 0.2870 - val_loss: 0.1791 - val_mean_absolute_error: 0.2818
# Epoch 139/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1423 - mean_absolute_error: 0.2853 - val_loss: 0.1822 - val_mean_absolute_error: 0.2821
# Epoch 140/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1475 - mean_absolute_error: 0.2907 - val_loss: 0.1740 - val_mean_absolute_error: 0.2722
# Epoch 141/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1389 - mean_absolute_error: 0.2820 - val_loss: 0.1784 - val_mean_absolute_error: 0.2788
# Epoch 142/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1401 - mean_absolute_error: 0.2836 - val_loss: 0.1773 - val_mean_absolute_error: 0.2765
# Epoch 143/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1388 - mean_absolute_error: 0.2823 - val_loss: 0.1727 - val_mean_absolute_error: 0.2722
# Epoch 144/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1380 - mean_absolute_error: 0.2817 - val_loss: 0.1749 - val_mean_absolute_error: 0.2744
# Epoch 145/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1357 - mean_absolute_error: 0.2791 - val_loss: 0.1736 - val_mean_absolute_error: 0.2725
# Epoch 146/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1365 - mean_absolute_error: 0.2802 - val_loss: 0.1788 - val_mean_absolute_error: 0.2809
# Epoch 147/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1345 - mean_absolute_error: 0.2780 - val_loss: 0.1738 - val_mean_absolute_error: 0.2723
# Epoch 148/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1373 - mean_absolute_error: 0.2812 - val_loss: 0.1787 - val_mean_absolute_error: 0.2800
# Epoch 149/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1359 - mean_absolute_error: 0.2796 - val_loss: 0.1717 - val_mean_absolute_error: 0.2711
# Epoch 150/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1364 - mean_absolute_error: 0.2802 - val_loss: 0.1710 - val_mean_absolute_error: 0.2705
# Epoch 151/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1331 - mean_absolute_error: 0.2761 - val_loss: 0.2852 - val_mean_absolute_error: 0.3705
# Epoch 152/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1431 - mean_absolute_error: 0.2867 - val_loss: 0.1704 - val_mean_absolute_error: 0.2692
# Epoch 153/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1352 - mean_absolute_error: 0.2788 - val_loss: 0.1714 - val_mean_absolute_error: 0.2728
# Epoch 154/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1355 - mean_absolute_error: 0.2795 - val_loss: 0.1726 - val_mean_absolute_error: 0.2728
# Epoch 155/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1312 - mean_absolute_error: 0.2746 - val_loss: 0.1717 - val_mean_absolute_error: 0.2709
# Epoch 156/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1354 - mean_absolute_error: 0.2791 - val_loss: 0.1949 - val_mean_absolute_error: 0.2952
# Epoch 157/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1321 - mean_absolute_error: 0.2750 - val_loss: 0.1834 - val_mean_absolute_error: 0.2827
# Epoch 158/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1373 - mean_absolute_error: 0.2811 - val_loss: 0.2110 - val_mean_absolute_error: 0.3172
# Epoch 159/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1369 - mean_absolute_error: 0.2802 - val_loss: 0.1879 - val_mean_absolute_error: 0.2911
# Epoch 160/200
# 105/105 [==============================] - 2s 20ms/step - loss: 0.1458 - mean_absolute_error: 0.2870 - val_loss: 0.1843 - val_mean_absolute_error: 0.2852
# Epoch 161/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1403 - mean_absolute_error: 0.2825 - val_loss: 0.1692 - val_mean_absolute_error: 0.2682
# Epoch 162/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1355 - mean_absolute_error: 0.2799 - val_loss: 0.1673 - val_mean_absolute_error: 0.2643
# Epoch 163/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1344 - mean_absolute_error: 0.2788 - val_loss: 0.1700 - val_mean_absolute_error: 0.2680
# Epoch 164/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1360 - mean_absolute_error: 0.2778 - val_loss: 1.5353 - val_mean_absolute_error: 0.8704
# Epoch 165/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1989 - mean_absolute_error: 0.3271 - val_loss: 0.1768 - val_mean_absolute_error: 0.2779
# Epoch 166/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1675 - mean_absolute_error: 0.3024 - val_loss: 0.1747 - val_mean_absolute_error: 0.2773
# Epoch 167/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1487 - mean_absolute_error: 0.2887 - val_loss: 0.1722 - val_mean_absolute_error: 0.2724
# Epoch 168/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1405 - mean_absolute_error: 0.2844 - val_loss: 0.1736 - val_mean_absolute_error: 0.2729
# Epoch 169/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1414 - mean_absolute_error: 0.2834 - val_loss: 2.1775 - val_mean_absolute_error: 0.9510
# Epoch 170/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2092 - mean_absolute_error: 0.3249 - val_loss: 0.1988 - val_mean_absolute_error: 0.3041
# Epoch 171/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1646 - mean_absolute_error: 0.3022 - val_loss: 0.1906 - val_mean_absolute_error: 0.2961
# Epoch 172/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1481 - mean_absolute_error: 0.2893 - val_loss: 0.6754 - val_mean_absolute_error: 0.5789
# Epoch 173/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1747 - mean_absolute_error: 0.3121 - val_loss: 0.1835 - val_mean_absolute_error: 0.2848
# Epoch 174/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1487 - mean_absolute_error: 0.2925 - val_loss: 0.1750 - val_mean_absolute_error: 0.2749
# Epoch 175/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1438 - mean_absolute_error: 0.2882 - val_loss: 0.1790 - val_mean_absolute_error: 0.2798
# Epoch 176/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1426 - mean_absolute_error: 0.2871 - val_loss: 0.1746 - val_mean_absolute_error: 0.2744
# Epoch 177/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1366 - mean_absolute_error: 0.2807 - val_loss: 0.3320 - val_mean_absolute_error: 0.3834
# Epoch 178/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1405 - mean_absolute_error: 0.2849 - val_loss: 0.1728 - val_mean_absolute_error: 0.2720
# Epoch 179/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1358 - mean_absolute_error: 0.2803 - val_loss: 0.1838 - val_mean_absolute_error: 0.2861
# Epoch 180/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1353 - mean_absolute_error: 0.2802 - val_loss: 0.1718 - val_mean_absolute_error: 0.2714
# Epoch 181/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1323 - mean_absolute_error: 0.2765 - val_loss: 0.1749 - val_mean_absolute_error: 0.2774
# Epoch 182/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1338 - mean_absolute_error: 0.2775 - val_loss: 0.2162 - val_mean_absolute_error: 0.3212
# Epoch 183/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1404 - mean_absolute_error: 0.2839 - val_loss: 2.8226 - val_mean_absolute_error: 1.0829
# Epoch 184/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1525 - mean_absolute_error: 0.2916 - val_loss: 0.1987 - val_mean_absolute_error: 0.3006
# Epoch 185/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1401 - mean_absolute_error: 0.2850 - val_loss: 0.1732 - val_mean_absolute_error: 0.2737
# Epoch 186/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1349 - mean_absolute_error: 0.2798 - val_loss: 0.1730 - val_mean_absolute_error: 0.2740
# Epoch 187/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1325 - mean_absolute_error: 0.2771 - val_loss: 0.1740 - val_mean_absolute_error: 0.2737
# Epoch 188/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1290 - mean_absolute_error: 0.2729 - val_loss: 0.1782 - val_mean_absolute_error: 0.2793
# Epoch 189/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1301 - mean_absolute_error: 0.2746 - val_loss: 0.1735 - val_mean_absolute_error: 0.2726
# Epoch 190/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1278 - mean_absolute_error: 0.2720 - val_loss: 0.1739 - val_mean_absolute_error: 0.2743
# Epoch 191/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1295 - mean_absolute_error: 0.2746 - val_loss: 0.1770 - val_mean_absolute_error: 0.2783
# Epoch 192/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1284 - mean_absolute_error: 0.2731 - val_loss: 0.1723 - val_mean_absolute_error: 0.2707
# Epoch 193/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1248 - mean_absolute_error: 0.2693 - val_loss: 0.1721 - val_mean_absolute_error: 0.2716
# Epoch 194/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1229 - mean_absolute_error: 0.2670 - val_loss: 0.1732 - val_mean_absolute_error: 0.2726
# Epoch 195/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1266 - mean_absolute_error: 0.2708 - val_loss: 0.1732 - val_mean_absolute_error: 0.2720
# Epoch 196/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1245 - mean_absolute_error: 0.2688 - val_loss: 0.1774 - val_mean_absolute_error: 0.2776
# Epoch 197/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1248 - mean_absolute_error: 0.2696 - val_loss: 0.1752 - val_mean_absolute_error: 0.2740
# Epoch 198/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1262 - mean_absolute_error: 0.2711 - val_loss: 0.1783 - val_mean_absolute_error: 0.2790
# Epoch 199/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1231 - mean_absolute_error: 0.2675 - val_loss: 0.1766 - val_mean_absolute_error: 0.2763
# Epoch 200/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1250 - mean_absolute_error: 0.2696 - val_loss: 0.1747 - val_mean_absolute_error: 0.2747
# Epoch 1/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1234 - mean_absolute_error: 0.2683 - val_loss: 0.1717 - val_mean_absolute_error: 0.2698
# Epoch 2/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1197 - mean_absolute_error: 0.2635 - val_loss: 0.1740 - val_mean_absolute_error: 0.2730
# Epoch 3/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1200 - mean_absolute_error: 0.2634 - val_loss: 0.1730 - val_mean_absolute_error: 0.2719
# Epoch 4/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1210 - mean_absolute_error: 0.2648 - val_loss: 0.1726 - val_mean_absolute_error: 0.2709
# Epoch 5/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1196 - mean_absolute_error: 0.2631 - val_loss: 0.1779 - val_mean_absolute_error: 0.2803
# Epoch 6/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1207 - mean_absolute_error: 0.2648 - val_loss: 0.1985 - val_mean_absolute_error: 0.3008
# Epoch 7/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1223 - mean_absolute_error: 0.2665 - val_loss: 0.1861 - val_mean_absolute_error: 0.2870
# Epoch 8/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1198 - mean_absolute_error: 0.2636 - val_loss: 0.1772 - val_mean_absolute_error: 0.2773
# Epoch 9/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1238 - mean_absolute_error: 0.2690 - val_loss: 0.1742 - val_mean_absolute_error: 0.2735
# Epoch 10/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1199 - mean_absolute_error: 0.2643 - val_loss: 0.1723 - val_mean_absolute_error: 0.2708
# Epoch 11/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1212 - mean_absolute_error: 0.2635 - val_loss: 1.9198 - val_mean_absolute_error: 0.8445
# Epoch 12/200
# 105/105 [==============================] - 2s 20ms/step - loss: 0.1539 - mean_absolute_error: 0.2890 - val_loss: 0.1765 - val_mean_absolute_error: 0.2750
# Epoch 13/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1295 - mean_absolute_error: 0.2742 - val_loss: 0.1813 - val_mean_absolute_error: 0.2812
# Epoch 14/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1231 - mean_absolute_error: 0.2664 - val_loss: 0.5381 - val_mean_absolute_error: 0.4555
# Epoch 15/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1315 - mean_absolute_error: 0.2761 - val_loss: 0.1769 - val_mean_absolute_error: 0.2744
# Epoch 16/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1211 - mean_absolute_error: 0.2651 - val_loss: 0.1799 - val_mean_absolute_error: 0.2784
# Epoch 17/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1226 - mean_absolute_error: 0.2675 - val_loss: 0.1730 - val_mean_absolute_error: 0.2706
# Epoch 18/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1234 - mean_absolute_error: 0.2675 - val_loss: 1.4832 - val_mean_absolute_error: 0.7368
# Epoch 19/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1425 - mean_absolute_error: 0.2838 - val_loss: 0.1804 - val_mean_absolute_error: 0.2824
# Epoch 20/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1240 - mean_absolute_error: 0.2683 - val_loss: 0.1748 - val_mean_absolute_error: 0.2716
# Epoch 21/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1227 - mean_absolute_error: 0.2675 - val_loss: 0.1708 - val_mean_absolute_error: 0.2681
# Epoch 22/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1170 - mean_absolute_error: 0.2613 - val_loss: 0.1740 - val_mean_absolute_error: 0.2707
# Epoch 23/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1173 - mean_absolute_error: 0.2616 - val_loss: 0.1730 - val_mean_absolute_error: 0.2698
# Epoch 24/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1187 - mean_absolute_error: 0.2634 - val_loss: 0.1732 - val_mean_absolute_error: 0.2699
# Epoch 25/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1189 - mean_absolute_error: 0.2639 - val_loss: 0.1753 - val_mean_absolute_error: 0.2730
# Epoch 26/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1197 - mean_absolute_error: 0.2648 - val_loss: 0.1748 - val_mean_absolute_error: 0.2716
# Epoch 27/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1211 - mean_absolute_error: 0.2660 - val_loss: 0.1731 - val_mean_absolute_error: 0.2695
# Epoch 28/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1188 - mean_absolute_error: 0.2638 - val_loss: 0.1732 - val_mean_absolute_error: 0.2716
# Epoch 29/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1172 - mean_absolute_error: 0.2615 - val_loss: 0.1762 - val_mean_absolute_error: 0.2739
# Epoch 30/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1184 - mean_absolute_error: 0.2634 - val_loss: 0.1759 - val_mean_absolute_error: 0.2739
# Epoch 31/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1142 - mean_absolute_error: 0.2585 - val_loss: 0.1788 - val_mean_absolute_error: 0.2780
# Epoch 32/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1190 - mean_absolute_error: 0.2645 - val_loss: 0.1735 - val_mean_absolute_error: 0.2705
# Epoch 33/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1157 - mean_absolute_error: 0.2603 - val_loss: 0.1742 - val_mean_absolute_error: 0.2706
# Epoch 34/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1192 - mean_absolute_error: 0.2640 - val_loss: 0.1811 - val_mean_absolute_error: 0.2791
# Epoch 35/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1157 - mean_absolute_error: 0.2604 - val_loss: 0.1754 - val_mean_absolute_error: 0.2725
# Epoch 36/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1154 - mean_absolute_error: 0.2604 - val_loss: 0.1746 - val_mean_absolute_error: 0.2711
# Epoch 37/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1144 - mean_absolute_error: 0.2590 - val_loss: 0.1764 - val_mean_absolute_error: 0.2757
# Epoch 38/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1156 - mean_absolute_error: 0.2600 - val_loss: 0.1740 - val_mean_absolute_error: 0.2710
# Epoch 39/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1134 - mean_absolute_error: 0.2575 - val_loss: 0.1784 - val_mean_absolute_error: 0.2769
# Epoch 40/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1147 - mean_absolute_error: 0.2596 - val_loss: 0.1762 - val_mean_absolute_error: 0.2746
# Epoch 41/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1138 - mean_absolute_error: 0.2588 - val_loss: 0.1751 - val_mean_absolute_error: 0.2723
# Epoch 42/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1129 - mean_absolute_error: 0.2576 - val_loss: 0.1733 - val_mean_absolute_error: 0.2707
# Epoch 43/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1128 - mean_absolute_error: 0.2567 - val_loss: 0.1809 - val_mean_absolute_error: 0.2818
# Epoch 44/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1266 - mean_absolute_error: 0.2664 - val_loss: 0.1706 - val_mean_absolute_error: 0.2675
# Epoch 45/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1178 - mean_absolute_error: 0.2605 - val_loss: 0.1730 - val_mean_absolute_error: 0.2706
# Epoch 46/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1134 - mean_absolute_error: 0.2582 - val_loss: 0.1739 - val_mean_absolute_error: 0.2733
# Epoch 47/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1118 - mean_absolute_error: 0.2561 - val_loss: 0.1761 - val_mean_absolute_error: 0.2742
# Epoch 48/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1127 - mean_absolute_error: 0.2575 - val_loss: 0.1739 - val_mean_absolute_error: 0.2721
# Epoch 49/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1130 - mean_absolute_error: 0.2581 - val_loss: 0.1733 - val_mean_absolute_error: 0.2708
# Epoch 50/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1148 - mean_absolute_error: 0.2593 - val_loss: 0.1846 - val_mean_absolute_error: 0.2846
# Epoch 51/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1142 - mean_absolute_error: 0.2584 - val_loss: 2.1131 - val_mean_absolute_error: 0.8601
# Epoch 52/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1511 - mean_absolute_error: 0.2890 - val_loss: 0.1779 - val_mean_absolute_error: 0.2771
# Epoch 53/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1205 - mean_absolute_error: 0.2649 - val_loss: 0.1792 - val_mean_absolute_error: 0.2799
# Epoch 54/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1196 - mean_absolute_error: 0.2648 - val_loss: 0.1784 - val_mean_absolute_error: 0.2765
# Epoch 55/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1167 - mean_absolute_error: 0.2619 - val_loss: 0.1837 - val_mean_absolute_error: 0.2826
# Epoch 56/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1152 - mean_absolute_error: 0.2600 - val_loss: 0.1871 - val_mean_absolute_error: 0.2879
# Epoch 57/200
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1127 - mean_absolute_error: 0.2577 - val_loss: 0.1821 - val_mean_absolute_error: 0.2802
# Epoch 58/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1163 - mean_absolute_error: 0.2621 - val_loss: 0.1766 - val_mean_absolute_error: 0.2742
# Epoch 59/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1127 - mean_absolute_error: 0.2582 - val_loss: 0.1747 - val_mean_absolute_error: 0.2713
# Epoch 60/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1078 - mean_absolute_error: 0.2519 - val_loss: 0.1841 - val_mean_absolute_error: 0.2830
# Epoch 61/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1116 - mean_absolute_error: 0.2564 - val_loss: 0.1769 - val_mean_absolute_error: 0.2755
# Epoch 62/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1090 - mean_absolute_error: 0.2534 - val_loss: 0.1756 - val_mean_absolute_error: 0.2729
# Epoch 63/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1060 - mean_absolute_error: 0.2495 - val_loss: 0.1742 - val_mean_absolute_error: 0.2717
# Epoch 64/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1087 - mean_absolute_error: 0.2526 - val_loss: 0.1755 - val_mean_absolute_error: 0.2719
# Epoch 65/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1105 - mean_absolute_error: 0.2557 - val_loss: 0.1743 - val_mean_absolute_error: 0.2711
# Epoch 66/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1138 - mean_absolute_error: 0.2571 - val_loss: 5.3533 - val_mean_absolute_error: 1.6051
# Epoch 67/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.2959 - mean_absolute_error: 0.3873 - val_loss: 0.2063 - val_mean_absolute_error: 0.3152
# Epoch 68/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1881 - mean_absolute_error: 0.3186 - val_loss: 0.1947 - val_mean_absolute_error: 0.2966
# Epoch 69/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1550 - mean_absolute_error: 0.2930 - val_loss: 0.1769 - val_mean_absolute_error: 0.2798
# Epoch 70/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1410 - mean_absolute_error: 0.2824 - val_loss: 0.1821 - val_mean_absolute_error: 0.2847
# Epoch 71/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1305 - mean_absolute_error: 0.2741 - val_loss: 0.1841 - val_mean_absolute_error: 0.2870
# Epoch 72/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1403 - mean_absolute_error: 0.2812 - val_loss: 0.1710 - val_mean_absolute_error: 0.2695
# Epoch 73/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1305 - mean_absolute_error: 0.2715 - val_loss: 0.1763 - val_mean_absolute_error: 0.2760
# Epoch 74/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1256 - mean_absolute_error: 0.2711 - val_loss: 0.1714 - val_mean_absolute_error: 0.2685
# Epoch 75/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1240 - mean_absolute_error: 0.2704 - val_loss: 0.1735 - val_mean_absolute_error: 0.2737
# Epoch 76/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1200 - mean_absolute_error: 0.2656 - val_loss: 0.1714 - val_mean_absolute_error: 0.2695
# Epoch 77/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1167 - mean_absolute_error: 0.2625 - val_loss: 0.1700 - val_mean_absolute_error: 0.2681
# Epoch 78/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1182 - mean_absolute_error: 0.2642 - val_loss: 0.1756 - val_mean_absolute_error: 0.2750
# Epoch 79/200
# 105/105 [==============================] - 2s 20ms/step - loss: 0.1176 - mean_absolute_error: 0.2631 - val_loss: 0.1754 - val_mean_absolute_error: 0.2726
# Epoch 80/200
# 105/105 [==============================] - 2s 20ms/step - loss: 0.1160 - mean_absolute_error: 0.2616 - val_loss: 0.1779 - val_mean_absolute_error: 0.2774
# Epoch 81/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1207 - mean_absolute_error: 0.2669 - val_loss: 0.1687 - val_mean_absolute_error: 0.2653
# Epoch 82/200
# 105/105 [==============================] - 2s 18ms/step - loss: 0.1104 - mean_absolute_error: 0.2555 - val_loss: 0.1694 - val_mean_absolute_error: 0.2656
# Epoch 83/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1151 - mean_absolute_error: 0.2611 - val_loss: 0.1703 - val_mean_absolute_error: 0.2690
# Epoch 84/200
# 105/105 [==============================] - 2s 20ms/step - loss: 0.1130 - mean_absolute_error: 0.2586 - val_loss: 0.1718 - val_mean_absolute_error: 0.2688
# Epoch 85/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1097 - mean_absolute_error: 0.2542 - val_loss: 0.1682 - val_mean_absolute_error: 0.2655
# Epoch 86/200
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1117 - mean_absolute_error: 0.2562 - val_loss: 0.3051 - val_mean_absolute_error: 0.3560
# Epoch 87/200
# ...
# Epoch 26/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0484 - mean_absolute_error: 0.1698 - val_loss: 0.1832 - val_mean_absolute_error: 0.2823
# Epoch 27/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0453 - mean_absolute_error: 0.1644 - val_loss: 0.1881 - val_mean_absolute_error: 0.2874
# Epoch 28/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0502 - mean_absolute_error: 0.1715 - val_loss: 0.1832 - val_mean_absolute_error: 0.2812
# Epoch 29/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0453 - mean_absolute_error: 0.1641 - val_loss: 0.1796 - val_mean_absolute_error: 0.2770
# Epoch 30/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0448 - mean_absolute_error: 0.1639 - val_loss: 0.1791 - val_mean_absolute_error: 0.2770
# Epoch 31/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0451 - mean_absolute_error: 0.1642 - val_loss: 0.1773 - val_mean_absolute_error: 0.2743
# Epoch 32/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0464 - mean_absolute_error: 0.1667 - val_loss: 0.1815 - val_mean_absolute_error: 0.2813
# Epoch 33/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0447 - mean_absolute_error: 0.1635 - val_loss: 0.1849 - val_mean_absolute_error: 0.2845
# Epoch 34/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0435 - mean_absolute_error: 0.1617 - val_loss: 0.1813 - val_mean_absolute_error: 0.2804
# Epoch 35/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0423 - mean_absolute_error: 0.1592 - val_loss: 0.1849 - val_mean_absolute_error: 0.2844
# Epoch 36/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0434 - mean_absolute_error: 0.1608 - val_loss: 0.1789 - val_mean_absolute_error: 0.2774
# Epoch 37/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0436 - mean_absolute_error: 0.1610 - val_loss: 0.1804 - val_mean_absolute_error: 0.2781
# Epoch 38/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0451 - mean_absolute_error: 0.1634 - val_loss: 0.1871 - val_mean_absolute_error: 0.2871
# Epoch 39/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0447 - mean_absolute_error: 0.1637 - val_loss: 0.1789 - val_mean_absolute_error: 0.2765
# Epoch 40/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0426 - mean_absolute_error: 0.1589 - val_loss: 0.1942 - val_mean_absolute_error: 0.2939
# Epoch 41/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0475 - mean_absolute_error: 0.1660 - val_loss: 0.1953 - val_mean_absolute_error: 0.2976
# Epoch 42/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0499 - mean_absolute_error: 0.1713 - val_loss: 0.1790 - val_mean_absolute_error: 0.2777
# Epoch 43/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0455 - mean_absolute_error: 0.1645 - val_loss: 0.1808 - val_mean_absolute_error: 0.2800
# Epoch 44/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0443 - mean_absolute_error: 0.1630 - val_loss: 0.1780 - val_mean_absolute_error: 0.2757
# Epoch 45/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0431 - mean_absolute_error: 0.1596 - val_loss: 0.1828 - val_mean_absolute_error: 0.2813
# Epoch 46/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0465 - mean_absolute_error: 0.1667 - val_loss: 0.1818 - val_mean_absolute_error: 0.2803
# Epoch 47/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0448 - mean_absolute_error: 0.1636 - val_loss: 0.1791 - val_mean_absolute_error: 0.2769
# Epoch 48/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0436 - mean_absolute_error: 0.1609 - val_loss: 0.1819 - val_mean_absolute_error: 0.2809
# Epoch 49/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0429 - mean_absolute_error: 0.1603 - val_loss: 0.1807 - val_mean_absolute_error: 0.2789
# Epoch 50/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0417 - mean_absolute_error: 0.1577 - val_loss: 0.1776 - val_mean_absolute_error: 0.2766
# Epoch 51/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0424 - mean_absolute_error: 0.1591 - val_loss: 0.1784 - val_mean_absolute_error: 0.2765
# Epoch 52/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0447 - mean_absolute_error: 0.1634 - val_loss: 0.1817 - val_mean_absolute_error: 0.2807
# Epoch 53/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0426 - mean_absolute_error: 0.1592 - val_loss: 0.1788 - val_mean_absolute_error: 0.2770
# Epoch 54/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0408 - mean_absolute_error: 0.1562 - val_loss: 0.1789 - val_mean_absolute_error: 0.2775
# Epoch 55/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0416 - mean_absolute_error: 0.1572 - val_loss: 0.1836 - val_mean_absolute_error: 0.2833
# Epoch 56/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0457 - mean_absolute_error: 0.1652 - val_loss: 0.1783 - val_mean_absolute_error: 0.2762
# Epoch 57/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0426 - mean_absolute_error: 0.1600 - val_loss: 0.1789 - val_mean_absolute_error: 0.2768
# Epoch 58/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0416 - mean_absolute_error: 0.1580 - val_loss: 0.1780 - val_mean_absolute_error: 0.2761
# Epoch 59/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0406 - mean_absolute_error: 0.1560 - val_loss: 0.1775 - val_mean_absolute_error: 0.2757
# Epoch 60/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0397 - mean_absolute_error: 0.1542 - val_loss: 0.1775 - val_mean_absolute_error: 0.2759
# Epoch 61/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0403 - mean_absolute_error: 0.1553 - val_loss: 0.1770 - val_mean_absolute_error: 0.2740
# Epoch 62/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0387 - mean_absolute_error: 0.1516 - val_loss: 0.1768 - val_mean_absolute_error: 0.2754
# Epoch 63/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0422 - mean_absolute_error: 0.1567 - val_loss: 0.1767 - val_mean_absolute_error: 0.2744
# Epoch 64/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0427 - mean_absolute_error: 0.1598 - val_loss: 0.1783 - val_mean_absolute_error: 0.2761
# Epoch 65/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0411 - mean_absolute_error: 0.1568 - val_loss: 0.1825 - val_mean_absolute_error: 0.2806
# Epoch 66/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0425 - mean_absolute_error: 0.1594 - val_loss: 0.1841 - val_mean_absolute_error: 0.2808
# Epoch 67/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0407 - mean_absolute_error: 0.1556 - val_loss: 0.2196 - val_mean_absolute_error: 0.3085
# Epoch 68/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0422 - mean_absolute_error: 0.1577 - val_loss: 0.1970 - val_mean_absolute_error: 0.2913
# Epoch 69/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0430 - mean_absolute_error: 0.1602 - val_loss: 0.1883 - val_mean_absolute_error: 0.2827
# Epoch 70/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0438 - mean_absolute_error: 0.1601 - val_loss: 0.1924 - val_mean_absolute_error: 0.2899
# Epoch 71/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0461 - mean_absolute_error: 0.1648 - val_loss: 0.1863 - val_mean_absolute_error: 0.2829
# Epoch 72/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0433 - mean_absolute_error: 0.1604 - val_loss: 0.1850 - val_mean_absolute_error: 0.2826
# Epoch 73/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0415 - mean_absolute_error: 0.1572 - val_loss: 0.1851 - val_mean_absolute_error: 0.2833
# Epoch 74/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0422 - mean_absolute_error: 0.1581 - val_loss: 0.1839 - val_mean_absolute_error: 0.2820
# Epoch 75/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0431 - mean_absolute_error: 0.1603 - val_loss: 0.1835 - val_mean_absolute_error: 0.2813
# Epoch 76/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0420 - mean_absolute_error: 0.1578 - val_loss: 0.1889 - val_mean_absolute_error: 0.2871
# Epoch 77/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0436 - mean_absolute_error: 0.1616 - val_loss: 0.1831 - val_mean_absolute_error: 0.2795
# Epoch 78/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0423 - mean_absolute_error: 0.1595 - val_loss: 0.1835 - val_mean_absolute_error: 0.2802
# Epoch 79/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0429 - mean_absolute_error: 0.1603 - val_loss: 0.1825 - val_mean_absolute_error: 0.2790
# Epoch 80/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0421 - mean_absolute_error: 0.1591 - val_loss: 0.1822 - val_mean_absolute_error: 0.2779
# Epoch 81/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0395 - mean_absolute_error: 0.1535 - val_loss: 0.1810 - val_mean_absolute_error: 0.2768
# Epoch 82/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0420 - mean_absolute_error: 0.1578 - val_loss: 0.1828 - val_mean_absolute_error: 0.2794
# Epoch 83/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0432 - mean_absolute_error: 0.1598 - val_loss: 0.1822 - val_mean_absolute_error: 0.2792
# Epoch 84/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0405 - mean_absolute_error: 0.1549 - val_loss: 0.1842 - val_mean_absolute_error: 0.2810
# Epoch 85/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0411 - mean_absolute_error: 0.1558 - val_loss: 0.1855 - val_mean_absolute_error: 0.2836
# Epoch 86/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0427 - mean_absolute_error: 0.1593 - val_loss: 0.1810 - val_mean_absolute_error: 0.2787
# Epoch 87/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0412 - mean_absolute_error: 0.1566 - val_loss: 0.1815 - val_mean_absolute_error: 0.2795
# Epoch 88/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0423 - mean_absolute_error: 0.1593 - val_loss: 0.1803 - val_mean_absolute_error: 0.2774
# Epoch 89/200
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0411 - mean_absolute_error: 0.1566 - val_loss: 0.1833 - val_mean_absolute_error: 0.2815
# Epoch 90/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0402 - mean_absolute_error: 0.1546 - val_loss: 0.1805 - val_mean_absolute_error: 0.2778
# Epoch 91/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0410 - mean_absolute_error: 0.1566 - val_loss: 0.1802 - val_mean_absolute_error: 0.2778
# Epoch 92/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0426 - mean_absolute_error: 0.1595 - val_loss: 0.1792 - val_mean_absolute_error: 0.2762
# Epoch 93/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0417 - mean_absolute_error: 0.1584 - val_loss: 0.1809 - val_mean_absolute_error: 0.2780
# Epoch 94/200
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0396 - mean_absolute_error: 0.1539 - val_loss: 0.1842 - val_mean_absolute_error: 0.2826
# Epoch 95/200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0394 - mean_absolute_error: 0.1534 - val_loss: 0.1820 - val_mean_absolute_error: 0.2793
# Epoch 96/200
#  4/27 [===>..........................] - ETA: 0s - loss: 0.0368 - mean_absolute_error: 0.1491
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-93be4656d4e9> in <module>
#       7     new_history = loaded_model.fit(trainX,trainY, epochs=200,
#       8                              validation_data=(testX,testY),
# ----> 9                              shuffle=True, batch_size=batch_size[i])
#      10
#
# ~\anaconda3\envs\deepLearning\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\anaconda3\envs\deepLearning\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~\anaconda3\envs\deepLearning\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~\anaconda3\envs\deepLearning\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\envs\deepLearning\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~\anaconda3\envs\deepLearning\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~\anaconda3\envs\deepLearning\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~\anaconda3\envs\deepLearning\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~\anaconda3\envs\deepLearning\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
#retrain by manually setting the hyperparameters each run
opt = tf.optimizers.SGD(lr=0.05)
met = tf.metrics.MeanAbsoluteError()
model.compile(loss=tf.losses.MSE, optimizer=opt, metrics=[met])
new_history = loaded_model.fit(trainX,trainY, epochs=200,
                             validation_data=(testX,testY),
                             shuffle=True, batch_size=64)
# Out:
# Epoch 1/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0937 - mean_absolute_error: 0.2292 - val_loss: 0.1708 - val_mean_absolute_error: 0.2706
# Epoch 2/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0897 - mean_absolute_error: 0.2235 - val_loss: 0.1689 - val_mean_absolute_error: 0.2675
# Epoch 3/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0909 - mean_absolute_error: 0.2254 - val_loss: 0.1688 - val_mean_absolute_error: 0.2673
# Epoch 4/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0920 - mean_absolute_error: 0.2268 - val_loss: 0.1770 - val_mean_absolute_error: 0.2776
# Epoch 5/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0931 - mean_absolute_error: 0.2283 - val_loss: 0.1769 - val_mean_absolute_error: 0.2793
# Epoch 6/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0923 - mean_absolute_error: 0.2277 - val_loss: 0.1698 - val_mean_absolute_error: 0.2696
# Epoch 7/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0932 - mean_absolute_error: 0.2281 - val_loss: 0.1930 - val_mean_absolute_error: 0.3003
# Epoch 8/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0981 - mean_absolute_error: 0.2328 - val_loss: 0.1701 - val_mean_absolute_error: 0.2704
# Epoch 9/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0932 - mean_absolute_error: 0.2291 - val_loss: 0.1683 - val_mean_absolute_error: 0.2679
# Epoch 10/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0912 - mean_absolute_error: 0.2262 - val_loss: 0.1674 - val_mean_absolute_error: 0.2659
# Epoch 11/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0913 - mean_absolute_error: 0.2248 - val_loss: 0.1832 - val_mean_absolute_error: 0.2871
# Epoch 12/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0967 - mean_absolute_error: 0.2325 - val_loss: 0.1721 - val_mean_absolute_error: 0.2722
# Epoch 13/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0918 - mean_absolute_error: 0.2267 - val_loss: 0.1722 - val_mean_absolute_error: 0.2718
# Epoch 14/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0903 - mean_absolute_error: 0.2251 - val_loss: 0.1676 - val_mean_absolute_error: 0.2656
# Epoch 15/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0921 - mean_absolute_error: 0.2278 - val_loss: 0.1672 - val_mean_absolute_error: 0.2656
# Epoch 16/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0922 - mean_absolute_error: 0.2282 - val_loss: 0.1721 - val_mean_absolute_error: 0.2723
# Epoch 17/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0899 - mean_absolute_error: 0.2242 - val_loss: 0.1786 - val_mean_absolute_error: 0.2811
# Epoch 18/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0908 - mean_absolute_error: 0.2258 - val_loss: 0.1711 - val_mean_absolute_error: 0.2704
# Epoch 19/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0889 - mean_absolute_error: 0.2232 - val_loss: 0.1732 - val_mean_absolute_error: 0.2727
# Epoch 20/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0889 - mean_absolute_error: 0.2230 - val_loss: 0.1708 - val_mean_absolute_error: 0.2721
# Epoch 21/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0909 - mean_absolute_error: 0.2260 - val_loss: 0.1713 - val_mean_absolute_error: 0.2708
# Epoch 22/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0911 - mean_absolute_error: 0.2251 - val_loss: 0.1738 - val_mean_absolute_error: 0.2741
# Epoch 23/200
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0967 - mean_absolute_error: 0.2318 - val_loss: 0.1717 - val_mean_absolute_error: 0.2725
# Epoch 24/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0920 - mean_absolute_error: 0.2269 - val_loss: 0.1818 - val_mean_absolute_error: 0.2818
# Epoch 25/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0936 - mean_absolute_error: 0.2298 - val_loss: 0.1847 - val_mean_absolute_error: 0.2868
# Epoch 26/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0915 - mean_absolute_error: 0.2272 - val_loss: 0.1710 - val_mean_absolute_error: 0.2708
# Epoch 27/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0945 - mean_absolute_error: 0.2268 - val_loss: 0.2719 - val_mean_absolute_error: 0.3736
# Epoch 28/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.1049 - mean_absolute_error: 0.2429 - val_loss: 0.1748 - val_mean_absolute_error: 0.2752
# Epoch 29/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0927 - mean_absolute_error: 0.2286 - val_loss: 0.1797 - val_mean_absolute_error: 0.2834
# Epoch 30/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0935 - mean_absolute_error: 0.2295 - val_loss: 0.1799 - val_mean_absolute_error: 0.2822
# Epoch 31/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0924 - mean_absolute_error: 0.2284 - val_loss: 0.1903 - val_mean_absolute_error: 0.2960
# Epoch 32/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0938 - mean_absolute_error: 0.2302 - val_loss: 0.1774 - val_mean_absolute_error: 0.2808
# Epoch 33/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0936 - mean_absolute_error: 0.2285 - val_loss: 0.2988 - val_mean_absolute_error: 0.3564
# Epoch 34/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0961 - mean_absolute_error: 0.2320 - val_loss: 0.1933 - val_mean_absolute_error: 0.3007
# Epoch 35/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0951 - mean_absolute_error: 0.2323 - val_loss: 0.1705 - val_mean_absolute_error: 0.2712
# Epoch 36/200
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0927 - mean_absolute_error: 0.2285 - val_loss: 0.1836 - val_mean_absolute_error: 0.2862
# Epoch 37/200
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0916 - mean_absolute_error: 0.2273 - val_loss: 0.1784 - val_mean_absolute_error: 0.2800
# Epoch 38/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0896 - mean_absolute_error: 0.2248 - val_loss: 0.1729 - val_mean_absolute_error: 0.2731
# Epoch 39/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0895 - mean_absolute_error: 0.2249 - val_loss: 0.1769 - val_mean_absolute_error: 0.2782
# Epoch 40/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0901 - mean_absolute_error: 0.2247 - val_loss: 0.2018 - val_mean_absolute_error: 0.3059
# Epoch 41/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.1004 - mean_absolute_error: 0.2314 - val_loss: 0.4603 - val_mean_absolute_error: 0.4572
# Epoch 42/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.1301 - mean_absolute_error: 0.2643 - val_loss: 0.1796 - val_mean_absolute_error: 0.2844
# Epoch 43/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.1015 - mean_absolute_error: 0.2402 - val_loss: 0.1812 - val_mean_absolute_error: 0.2828
# Epoch 44/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0983 - mean_absolute_error: 0.2352 - val_loss: 0.6239 - val_mean_absolute_error: 0.4476
# Epoch 45/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.1126 - mean_absolute_error: 0.2463 - val_loss: 0.1794 - val_mean_absolute_error: 0.2826
# Epoch 46/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0977 - mean_absolute_error: 0.2349 - val_loss: 0.1692 - val_mean_absolute_error: 0.2697
# Epoch 47/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0941 - mean_absolute_error: 0.2306 - val_loss: 0.1731 - val_mean_absolute_error: 0.2760
# Epoch 48/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0946 - mean_absolute_error: 0.2300 - val_loss: 0.2439 - val_mean_absolute_error: 0.3445
# Epoch 49/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.1490 - mean_absolute_error: 0.2734 - val_loss: 0.1739 - val_mean_absolute_error: 0.2758
# Epoch 50/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.1050 - mean_absolute_error: 0.2423 - val_loss: 0.1700 - val_mean_absolute_error: 0.2719
# Epoch 51/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0981 - mean_absolute_error: 0.2356 - val_loss: 0.1701 - val_mean_absolute_error: 0.2726
# Epoch 52/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0950 - mean_absolute_error: 0.2318 - val_loss: 0.1710 - val_mean_absolute_error: 0.2722
# Epoch 53/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0935 - mean_absolute_error: 0.2302 - val_loss: 0.1728 - val_mean_absolute_error: 0.2749
# Epoch 54/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0929 - mean_absolute_error: 0.2295 - val_loss: 0.1746 - val_mean_absolute_error: 0.2774
# Epoch 55/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0899 - mean_absolute_error: 0.2254 - val_loss: 0.1722 - val_mean_absolute_error: 0.2723
# Epoch 56/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0892 - mean_absolute_error: 0.2248 - val_loss: 0.1713 - val_mean_absolute_error: 0.2712
# Epoch 57/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0885 - mean_absolute_error: 0.2238 - val_loss: 0.1757 - val_mean_absolute_error: 0.2766
# Epoch 58/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0881 - mean_absolute_error: 0.2228 - val_loss: 0.1706 - val_mean_absolute_error: 0.2710
# Epoch 59/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0896 - mean_absolute_error: 0.2250 - val_loss: 0.1690 - val_mean_absolute_error: 0.2689
# Epoch 60/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0867 - mean_absolute_error: 0.2213 - val_loss: 0.1738 - val_mean_absolute_error: 0.2750
# Epoch 61/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0903 - mean_absolute_error: 0.2267 - val_loss: 0.1712 - val_mean_absolute_error: 0.2716
# Epoch 62/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0890 - mean_absolute_error: 0.2249 - val_loss: 0.1721 - val_mean_absolute_error: 0.2728
# Epoch 63/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0882 - mean_absolute_error: 0.2232 - val_loss: 0.1731 - val_mean_absolute_error: 0.2749
# Epoch 64/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0893 - mean_absolute_error: 0.2217 - val_loss: 0.5476 - val_mean_absolute_error: 0.4840
# Epoch 65/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.1506 - mean_absolute_error: 0.2689 - val_loss: 0.1810 - val_mean_absolute_error: 0.2842
# Epoch 66/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.1033 - mean_absolute_error: 0.2412 - val_loss: 0.1827 - val_mean_absolute_error: 0.2870
# Epoch 67/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.1032 - mean_absolute_error: 0.2416 - val_loss: 0.1738 - val_mean_absolute_error: 0.2753
# Epoch 68/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0963 - mean_absolute_error: 0.2338 - val_loss: 0.1757 - val_mean_absolute_error: 0.2779
# Epoch 69/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0920 - mean_absolute_error: 0.2285 - val_loss: 0.1723 - val_mean_absolute_error: 0.2725
# Epoch 70/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0915 - mean_absolute_error: 0.2280 - val_loss: 0.1763 - val_mean_absolute_error: 0.2784
# Epoch 71/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0926 - mean_absolute_error: 0.2294 - val_loss: 0.1690 - val_mean_absolute_error: 0.2686
# Epoch 72/200
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0882 - mean_absolute_error: 0.2239 - val_loss: 0.1712 - val_mean_absolute_error: 0.2709
# Epoch 73/200
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0898 - mean_absolute_error: 0.2261 - val_loss: 0.1765 - val_mean_absolute_error: 0.2774
# Epoch 74/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0876 - mean_absolute_error: 0.2227 - val_loss: 0.1707 - val_mean_absolute_error: 0.2708
# Epoch 75/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0884 - mean_absolute_error: 0.2245 - val_loss: 0.1738 - val_mean_absolute_error: 0.2751
# Epoch 76/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0887 - mean_absolute_error: 0.2245 - val_loss: 0.1730 - val_mean_absolute_error: 0.2739
# Epoch 77/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0880 - mean_absolute_error: 0.2242 - val_loss: 0.1708 - val_mean_absolute_error: 0.2700
# Epoch 78/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0855 - mean_absolute_error: 0.2199 - val_loss: 0.1753 - val_mean_absolute_error: 0.2766
# Epoch 79/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0846 - mean_absolute_error: 0.2189 - val_loss: 0.1739 - val_mean_absolute_error: 0.2747
# Epoch 80/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0857 - mean_absolute_error: 0.2200 - val_loss: 0.1706 - val_mean_absolute_error: 0.2704
# Epoch 81/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0874 - mean_absolute_error: 0.2234 - val_loss: 0.1730 - val_mean_absolute_error: 0.2740
# Epoch 82/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0857 - mean_absolute_error: 0.2209 - val_loss: 0.1714 - val_mean_absolute_error: 0.2720
# Epoch 83/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0855 - mean_absolute_error: 0.2199 - val_loss: 0.1853 - val_mean_absolute_error: 0.2900
# Epoch 84/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0944 - mean_absolute_error: 0.2320 - val_loss: 0.1705 - val_mean_absolute_error: 0.2709
# Epoch 85/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0882 - mean_absolute_error: 0.2245 - val_loss: 0.1752 - val_mean_absolute_error: 0.2772
# Epoch 86/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0861 - mean_absolute_error: 0.2213 - val_loss: 0.1712 - val_mean_absolute_error: 0.2717
# Epoch 87/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0874 - mean_absolute_error: 0.2233 - val_loss: 0.1727 - val_mean_absolute_error: 0.2733
# Epoch 88/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0846 - mean_absolute_error: 0.2195 - val_loss: 0.1708 - val_mean_absolute_error: 0.2713
# Epoch 89/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0838 - mean_absolute_error: 0.2182 - val_loss: 0.1720 - val_mean_absolute_error: 0.2718
# Epoch 90/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0840 - mean_absolute_error: 0.2186 - val_loss: 0.1711 - val_mean_absolute_error: 0.2723
# Epoch 91/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0854 - mean_absolute_error: 0.2211 - val_loss: 0.1699 - val_mean_absolute_error: 0.2699
# Epoch 92/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0826 - mean_absolute_error: 0.2169 - val_loss: 0.1701 - val_mean_absolute_error: 0.2699
# Epoch 93/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0826 - mean_absolute_error: 0.2171 - val_loss: 0.1704 - val_mean_absolute_error: 0.2691
# Epoch 94/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0833 - mean_absolute_error: 0.2181 - val_loss: 0.1705 - val_mean_absolute_error: 0.2706
# Epoch 95/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0813 - mean_absolute_error: 0.2150 - val_loss: 0.1724 - val_mean_absolute_error: 0.2724
# Epoch 96/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0839 - mean_absolute_error: 0.2189 - val_loss: 0.1691 - val_mean_absolute_error: 0.2681
# Epoch 97/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0830 - mean_absolute_error: 0.2178 - val_loss: 0.1693 - val_mean_absolute_error: 0.2701
# Epoch 98/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0819 - mean_absolute_error: 0.2157 - val_loss: 0.1758 - val_mean_absolute_error: 0.2783
# Epoch 99/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0819 - mean_absolute_error: 0.2162 - val_loss: 0.1710 - val_mean_absolute_error: 0.2710
# Epoch 100/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0821 - mean_absolute_error: 0.2164 - val_loss: 0.1714 - val_mean_absolute_error: 0.2728
# Epoch 101/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0817 - mean_absolute_error: 0.2158 - val_loss: 0.1708 - val_mean_absolute_error: 0.2706
# Epoch 102/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0825 - mean_absolute_error: 0.2165 - val_loss: 0.1904 - val_mean_absolute_error: 0.2927
# Epoch 103/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0856 - mean_absolute_error: 0.2198 - val_loss: 0.3715 - val_mean_absolute_error: 0.4254
# Epoch 104/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.1001 - mean_absolute_error: 0.2370 - val_loss: 0.2322 - val_mean_absolute_error: 0.3334
# Epoch 105/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.1030 - mean_absolute_error: 0.2414 - val_loss: 0.1748 - val_mean_absolute_error: 0.2759
# Epoch 106/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0891 - mean_absolute_error: 0.2257 - val_loss: 0.1857 - val_mean_absolute_error: 0.2882
# Epoch 107/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0911 - mean_absolute_error: 0.2281 - val_loss: 0.1844 - val_mean_absolute_error: 0.2873
# Epoch 108/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0984 - mean_absolute_error: 0.2365 - val_loss: 0.1797 - val_mean_absolute_error: 0.2811
# Epoch 109/200
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0911 - mean_absolute_error: 0.2282 - val_loss: 0.1778 - val_mean_absolute_error: 0.2784
# Epoch 110/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0933 - mean_absolute_error: 0.2304 - val_loss: 0.1773 - val_mean_absolute_error: 0.2787
# Epoch 111/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0879 - mean_absolute_error: 0.2244 - val_loss: 0.1756 - val_mean_absolute_error: 0.2759
# Epoch 112/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0870 - mean_absolute_error: 0.2233 - val_loss: 0.1839 - val_mean_absolute_error: 0.2856
# Epoch 113/200
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0868 - mean_absolute_error: 0.2228 - val_loss: 0.1770 - val_mean_absolute_error: 0.2775
# Epoch 114/200
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0850 - mean_absolute_error: 0.2192 - val_loss: 0.2438 - val_mean_absolute_error: 0.3321
# Epoch 115/200
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0951 - mean_absolute_error: 0.2319 - val_loss: 0.1826 - val_mean_absolute_error: 0.2851
# Epoch 116/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0882 - mean_absolute_error: 0.2255 - val_loss: 0.1744 - val_mean_absolute_error: 0.2748
# Epoch 117/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0860 - mean_absolute_error: 0.2225 - val_loss: 0.1794 - val_mean_absolute_error: 0.2812
# Epoch 118/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0827 - mean_absolute_error: 0.2177 - val_loss: 0.1754 - val_mean_absolute_error: 0.2762
# Epoch 119/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0827 - mean_absolute_error: 0.2179 - val_loss: 0.1741 - val_mean_absolute_error: 0.2740
# Epoch 120/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0827 - mean_absolute_error: 0.2175 - val_loss: 0.1751 - val_mean_absolute_error: 0.2753
# Epoch 121/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0858 - mean_absolute_error: 0.2219 - val_loss: 0.1813 - val_mean_absolute_error: 0.2843
# Epoch 122/200
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0849 - mean_absolute_error: 0.2211 - val_loss: 0.1764 - val_mean_absolute_error: 0.2769
# Epoch 123/200
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0827 - mean_absolute_error: 0.2171 - val_loss: 0.2785 - val_mean_absolute_error: 0.3415
# Epoch 124/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0894 - mean_absolute_error: 0.2265 - val_loss: 0.1773 - val_mean_absolute_error: 0.2774
# Epoch 125/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0852 - mean_absolute_error: 0.2217 - val_loss: 0.1741 - val_mean_absolute_error: 0.2731
# Epoch 126/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0816 - mean_absolute_error: 0.2164 - val_loss: 0.1757 - val_mean_absolute_error: 0.2754
# Epoch 127/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0816 - mean_absolute_error: 0.2159 - val_loss: 0.1746 - val_mean_absolute_error: 0.2737
# Epoch 128/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0828 - mean_absolute_error: 0.2182 - val_loss: 0.1751 - val_mean_absolute_error: 0.2747
# Epoch 129/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0804 - mean_absolute_error: 0.2139 - val_loss: 0.1827 - val_mean_absolute_error: 0.2866
# Epoch 130/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0851 - mean_absolute_error: 0.2186 - val_loss: 0.2662 - val_mean_absolute_error: 0.3488
# Epoch 131/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0927 - mean_absolute_error: 0.2295 - val_loss: 0.1896 - val_mean_absolute_error: 0.2913
# Epoch 132/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0848 - mean_absolute_error: 0.2210 - val_loss: 0.1742 - val_mean_absolute_error: 0.2743
# Epoch 133/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0820 - mean_absolute_error: 0.2171 - val_loss: 0.1747 - val_mean_absolute_error: 0.2750
# Epoch 134/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0795 - mean_absolute_error: 0.2137 - val_loss: 0.1749 - val_mean_absolute_error: 0.2748
# Epoch 135/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0801 - mean_absolute_error: 0.2142 - val_loss: 0.1760 - val_mean_absolute_error: 0.2769
# Epoch 136/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0837 - mean_absolute_error: 0.2194 - val_loss: 0.1762 - val_mean_absolute_error: 0.2767
# Epoch 137/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0832 - mean_absolute_error: 0.2165 - val_loss: 0.2508 - val_mean_absolute_error: 0.3384
# Epoch 138/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0878 - mean_absolute_error: 0.2241 - val_loss: 0.1807 - val_mean_absolute_error: 0.2821
# Epoch 139/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0826 - mean_absolute_error: 0.2180 - val_loss: 0.1766 - val_mean_absolute_error: 0.2767
# Epoch 140/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0825 - mean_absolute_error: 0.2181 - val_loss: 0.1744 - val_mean_absolute_error: 0.2739
# Epoch 141/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0805 - mean_absolute_error: 0.2152 - val_loss: 0.1762 - val_mean_absolute_error: 0.2769
# Epoch 142/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0802 - mean_absolute_error: 0.2146 - val_loss: 0.1775 - val_mean_absolute_error: 0.2790
# Epoch 143/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0798 - mean_absolute_error: 0.2141 - val_loss: 0.1780 - val_mean_absolute_error: 0.2781
# Epoch 144/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0786 - mean_absolute_error: 0.2126 - val_loss: 0.1811 - val_mean_absolute_error: 0.2820
# Epoch 145/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0815 - mean_absolute_error: 0.2166 - val_loss: 0.1763 - val_mean_absolute_error: 0.2754
# Epoch 146/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0793 - mean_absolute_error: 0.2134 - val_loss: 0.1747 - val_mean_absolute_error: 0.2737
# Epoch 147/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0793 - mean_absolute_error: 0.2131 - val_loss: 0.1783 - val_mean_absolute_error: 0.2795
# Epoch 148/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0802 - mean_absolute_error: 0.2144 - val_loss: 0.2110 - val_mean_absolute_error: 0.3174
# Epoch 149/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0933 - mean_absolute_error: 0.2309 - val_loss: 0.2012 - val_mean_absolute_error: 0.3078
# Epoch 150/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0848 - mean_absolute_error: 0.2213 - val_loss: 0.1778 - val_mean_absolute_error: 0.2781
# Epoch 151/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0839 - mean_absolute_error: 0.2204 - val_loss: 0.1789 - val_mean_absolute_error: 0.2783
# Epoch 152/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0819 - mean_absolute_error: 0.2146 - val_loss: 0.2186 - val_mean_absolute_error: 0.3266
# Epoch 153/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0959 - mean_absolute_error: 0.2328 - val_loss: 0.1874 - val_mean_absolute_error: 0.2896
# Epoch 154/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0865 - mean_absolute_error: 0.2227 - val_loss: 0.1840 - val_mean_absolute_error: 0.2857
# Epoch 155/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0833 - mean_absolute_error: 0.2182 - val_loss: 0.3041 - val_mean_absolute_error: 0.3698
# Epoch 156/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.1020 - mean_absolute_error: 0.2383 - val_loss: 0.1894 - val_mean_absolute_error: 0.2939
# Epoch 157/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0883 - mean_absolute_error: 0.2262 - val_loss: 0.1729 - val_mean_absolute_error: 0.2736
# Epoch 158/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0827 - mean_absolute_error: 0.2186 - val_loss: 0.1739 - val_mean_absolute_error: 0.2742
# Epoch 159/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0825 - mean_absolute_error: 0.2186 - val_loss: 0.1736 - val_mean_absolute_error: 0.2739
# Epoch 160/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0809 - mean_absolute_error: 0.2166 - val_loss: 0.1754 - val_mean_absolute_error: 0.2762
# Epoch 161/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0798 - mean_absolute_error: 0.2148 - val_loss: 0.1725 - val_mean_absolute_error: 0.2732
# Epoch 162/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0801 - mean_absolute_error: 0.2151 - val_loss: 0.1764 - val_mean_absolute_error: 0.2771
# Epoch 163/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0787 - mean_absolute_error: 0.2132 - val_loss: 0.1762 - val_mean_absolute_error: 0.2765
# Epoch 164/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0799 - mean_absolute_error: 0.2148 - val_loss: 0.1734 - val_mean_absolute_error: 0.2725
# Epoch 165/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0833 - mean_absolute_error: 0.2167 - val_loss: 0.1897 - val_mean_absolute_error: 0.2949
# Epoch 166/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0843 - mean_absolute_error: 0.2201 - val_loss: 0.1756 - val_mean_absolute_error: 0.2764
# Epoch 167/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0831 - mean_absolute_error: 0.2163 - val_loss: 0.2242 - val_mean_absolute_error: 0.3310
# Epoch 168/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.1284 - mean_absolute_error: 0.2575 - val_loss: 0.1822 - val_mean_absolute_error: 0.2844
# Epoch 169/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0939 - mean_absolute_error: 0.2307 - val_loss: 0.1871 - val_mean_absolute_error: 0.2912
# Epoch 170/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0853 - mean_absolute_error: 0.2220 - val_loss: 0.1799 - val_mean_absolute_error: 0.2807
# Epoch 171/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0841 - mean_absolute_error: 0.2208 - val_loss: 0.1762 - val_mean_absolute_error: 0.2769
# Epoch 172/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0830 - mean_absolute_error: 0.2180 - val_loss: 0.1965 - val_mean_absolute_error: 0.2994
# Epoch 173/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0871 - mean_absolute_error: 0.2238 - val_loss: 0.1775 - val_mean_absolute_error: 0.2789
# Epoch 174/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0825 - mean_absolute_error: 0.2184 - val_loss: 0.1827 - val_mean_absolute_error: 0.2833
# Epoch 175/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0820 - mean_absolute_error: 0.2182 - val_loss: 0.1777 - val_mean_absolute_error: 0.2787
# Epoch 176/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0810 - mean_absolute_error: 0.2163 - val_loss: 0.1776 - val_mean_absolute_error: 0.2780
# Epoch 177/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0812 - mean_absolute_error: 0.2170 - val_loss: 0.1829 - val_mean_absolute_error: 0.2858
# Epoch 178/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0827 - mean_absolute_error: 0.2192 - val_loss: 0.1817 - val_mean_absolute_error: 0.2839
# Epoch 179/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0790 - mean_absolute_error: 0.2136 - val_loss: 0.1762 - val_mean_absolute_error: 0.2763
# Epoch 180/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0776 - mean_absolute_error: 0.2119 - val_loss: 0.1813 - val_mean_absolute_error: 0.2826
# Epoch 181/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0777 - mean_absolute_error: 0.2124 - val_loss: 0.1750 - val_mean_absolute_error: 0.2757
# Epoch 182/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0817 - mean_absolute_error: 0.2135 - val_loss: 0.3053 - val_mean_absolute_error: 0.3958
# Epoch 183/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0946 - mean_absolute_error: 0.2287 - val_loss: 0.1931 - val_mean_absolute_error: 0.2952
# Epoch 184/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0827 - mean_absolute_error: 0.2191 - val_loss: 0.1800 - val_mean_absolute_error: 0.2813
# Epoch 185/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0787 - mean_absolute_error: 0.2137 - val_loss: 0.1816 - val_mean_absolute_error: 0.2821
# Epoch 186/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0773 - mean_absolute_error: 0.2111 - val_loss: 0.1915 - val_mean_absolute_error: 0.2945
# Epoch 187/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0819 - mean_absolute_error: 0.2182 - val_loss: 0.1805 - val_mean_absolute_error: 0.2799
# Epoch 188/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0780 - mean_absolute_error: 0.2125 - val_loss: 0.1791 - val_mean_absolute_error: 0.2788
# Epoch 189/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0771 - mean_absolute_error: 0.2114 - val_loss: 0.1834 - val_mean_absolute_error: 0.2841
# Epoch 190/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0779 - mean_absolute_error: 0.2129 - val_loss: 0.1788 - val_mean_absolute_error: 0.2788
# Epoch 191/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0773 - mean_absolute_error: 0.2122 - val_loss: 0.1806 - val_mean_absolute_error: 0.2809
# Epoch 192/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0779 - mean_absolute_error: 0.2125 - val_loss: 0.1815 - val_mean_absolute_error: 0.2823
# Epoch 193/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0773 - mean_absolute_error: 0.2121 - val_loss: 0.1789 - val_mean_absolute_error: 0.2784
# Epoch 194/200
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0760 - mean_absolute_error: 0.2103 - val_loss: 0.1794 - val_mean_absolute_error: 0.2799
# Epoch 195/200
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0761 - mean_absolute_error: 0.2105 - val_loss: 0.1799 - val_mean_absolute_error: 0.2797
# Epoch 196/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0741 - mean_absolute_error: 0.2073 - val_loss: 0.1785 - val_mean_absolute_error: 0.2783
# Epoch 197/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0785 - mean_absolute_error: 0.2137 - val_loss: 0.1803 - val_mean_absolute_error: 0.2810
# Epoch 198/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0738 - mean_absolute_error: 0.2069 - val_loss: 0.1765 - val_mean_absolute_error: 0.2758
# Epoch 199/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0755 - mean_absolute_error: 0.2099 - val_loss: 0.1798 - val_mean_absolute_error: 0.2804
# Epoch 200/200
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0738 - mean_absolute_error: 0.2072 - val_loss: 0.1787 - val_mean_absolute_error: 0.2783

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
trainPredict = scaler.inverse_transform(trainPredict)
trainY_invscaled= scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY_invscaled = scaler.inverse_transform([testY])

# calculate root mean squared error
from sklearn.metrics import mean_squared_error
trainScore = math.sqrt(mean_squared_error(trainY_invscaled[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))

testScore = math.sqrt(mean_squared_error(testY_invscaled[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))

trainPredict_reshaped = tf.expand_dims(np.squeeze(trainPredict),1)
testPredict_reshaped = tf.expand_dims(np.squeeze(testPredict),1)

# %%
#this only works when the predicted output is a number and not a vector
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[seq_size:len(trainPredict)+seq_size, :] = tf.expand_dims(np.squeeze(trainPredict),1)

# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(seq_size*2)+1:len(dataset)-1, :] = tf.expand_dims(np.squeeze(testPredict),1)

# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
#this will plot an input and its prediction
a = 0 #this selects the input sequence
out = loaded_model.predict(tf.expand_dims(trainX[a],1))
x = scaler.inverse_transform(trainX[a])
y = scaler.inverse_transform(out)
yy = y.flatten()
xx = x.flatten()

# print(xx)
# print(yy)

y1 = np.empty(len(xx)+len(yy))
y1[:] = np.nan
y1[len(xx):] = yy
plt.figure(figsize=(15, 5))
plt.plot(xx)
plt.plot(y1)

# %%
#runs the prediction for 200 times generate music from given initial sequence
#the initial sequence is the same as the one plotted above
x_in = trainX[a]
song_out = x_in
for i in range(200):  
    temp = loaded_model.predict(tf.expand_dims(x_in,1))
    song_out = np.append(song_out, temp)
    x_in = song_out[output_len*(i+1):]
    x_in = np.reshape(x_in, (1,-1))

song_out = scaler.inverse_transform(song_out).flatten()
plt.figure(figsize=(15, 5))
plt.plot(song_out, 'r')

# %%
#play the predicted music
int_data = song_out.astype(int)
samplerate= 44100/10
IPython.display.Audio(int_data, rate=samplerate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
